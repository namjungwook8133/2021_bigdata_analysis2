# %% [markdown]
# # 미세먼지 OpenApi 활용

# %%
import requests
import pandas as pd
import xmltodict
import json

# %%
url='http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?sidoName=서울&pageNo=1&numOfRows=100&returnType=xml&serviceKey=QKXDceSiFlOdWUSQHH%2F7tuEM7zc7rHrl5hzbfNp2USBIOcRh3rf92z%2FjkK8pLbjjaoGyypAUvwamTUqOTiUEUA%3D%3D&ver=1.0'
url
# Out:
# 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?sidoName=서울&pageNo=1&numOfRows=100&returnType=xml&serviceKey=QKXDceSiFlOdWUSQHH%2F7tuEM7zc7rHrl5hzbfNp2USBIOcRh3rf92z%2FjkK8pLbjjaoGyypAUvwamTUqOTiUEUA%3D%3D&ver=1.0'

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\r\n<response>\n  <header>\n    <resultCode>00</resultCode>\n    <resultMsg>NORMAL_CODE</resultMsg>\n  </header>\n  <body>\n    <items>\n      <item>\n        <so2Grade/>\n        <coFlag/>\n        <khaiValue>-</khaiValue>\n        <so2Value>-</so2Value>\n        <coValue>0.2</coValue>\n        <pm25Flag/>\n        <pm10Flag/>\n        <o3Grade>1</o3Grade>\n        <pm10Value>12</pm10Value>\n        <khaiGrade/>\n        <pm25Value>4</pm25Value>\n        <sidoName>서울</sidoName>\n        <no2Flag/>\n        <no2Grade>1</no2Grade>\n        <o3Flag/>\n        <pm25Grade/>\n        <so2Flag>장비점검</so2Flag>\n        <dataTime>2021-09-16 18:00</dataTime>\n        <coGrade>1</coGrade>\n        <no2Value>0.021</no2Value>\n        <stationName>중구</stationName>\n        <pm10Grade/>\n        <o3Value>0.025</o3Value>\n      </item>\n      <item>\n        <so2Grade>1</so2Grade>\n        <coFlag/>\n        <khaiValue>56</khaiValue>\n        <so2Value>0.003</
# ...

# %%
temp = xmltodict.parse(res.text)
temp
# Out:
# OrderedDict([('response',
#               OrderedDict([('header',
#                             OrderedDict([('resultCode', '00'),
#                                          ('resultMsg', 'NORMAL_CODE')])),
#                            ('body',
#                             OrderedDict([('items',
#                                           OrderedDict([('item',
#                                                         [OrderedDict([('so2Grade',
#                                                                        None),
#                                                                       ('coFlag',
#                                                                        None),
#                                                                       ('khaiValue',
#                                                                        '-'),
#                                                                       ('so2Value',
# ...

# %%
result = json.loads(json.dumps(temp)) 
result
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'},
#   'body': {'items': {'item': [{'so2Grade': None,
#       'coFlag': None,
#       'khaiValue': '-',
#       'so2Value': '-',
#       'coValue': '0.2',
#       'pm25Flag': None,
#       'pm10Flag': None,
#       'o3Grade': '1',
#       'pm10Value': '12',
#       'khaiGrade': None,
#       'pm25Value': '4',
#       'sidoName': '서울',
#       'no2Flag': None,
#       'no2Grade': '1',
#       'o3Flag': None,
#       'pm25Grade': None,
#       'so2Flag': '장비점검',
#       'dataTime': '2021-09-16 18:00',
#       'coGrade': '1',
#       'no2Value': '0.021',
#       'stationName': '중구',
#       'pm10Grade': None,
#       'o3Value': '0.025'},
#      {'so2Grade': '1',
#       'coFlag': None,
#       'khaiValue': '56',
#       'so2Value': '0.003',
#       'coValue': '0.6',
#       'pm25Flag': None,
#       'pm10Flag': None,
#       'o3Grade': '1',
#       'pm10Value': '35',
#       'khaiGrade': '2',
# ...

# %%
items =result['response']['body']['items']['item']

for item in items:
    print(item)
# Out:
# {'so2Grade': None, 'coFlag': None, 'khaiValue': '-', 'so2Value': '-', 'coValue': '0.2', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '12', 'khaiGrade': None, 'pm25Value': '4', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': None, 'so2Flag': '장비점검', 'dataTime': '2021-09-16 18:00', 'coGrade': '1', 'no2Value': '0.021', 'stationName': '중구', 'pm10Grade': None, 'o3Value': '0.025'}
# {'so2Grade': '1', 'coFlag': None, 'khaiValue': '56', 'so2Value': '0.003', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '1', 'pm10Value': '35', 'khaiGrade': '2', 'pm25Value': '13', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2021-09-16 18:00', 'coGrade': '1', 'no2Value': '0.021', 'stationName': '한강대로', 'pm10Grade': '2', 'o3Value': '0.020'}
# ...
